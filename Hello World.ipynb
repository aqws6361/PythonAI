# %%
print('Hello World')

# %% [markdown]
# 這是一個Jupyter Notebook

# %%
#安裝Pytorch
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118 --no-cache-dir
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.7 GB 7.9 MB/s eta 0:05:40
#      ---------------------------------------- 0.0/2.7 GB 4.9 MB/s eta 0:09:15
#      ---------------------------------------- 0.0/2.7 GB 6.4 MB/s eta 0:07:02
#      ---------------------------------------- 0.0/2.7 GB 6.4 MB/s eta 0:07:03
#      ---------------------------------------- 0.0/2.7 GB 6.3 MB/s eta 0:07:10
#      ---------------------------------------- 0.0/2.7 GB 6.2 MB/s eta 0:07:15
#      ---------------------------------------- 0.0/2.7 GB 6.2 MB/s eta 0:07:13
#      ---------------------------------------- 0.0/2.7 GB 6.2 MB/s eta 0:07:16
#      ---------------------------------------- 0.0/2.7 GB 6.2 MB/s eta 0:07:18
#      ---------------------------------------- 0.0/2.7 GB 6.2 MB/s eta 0:07:16
# ...

# %%
#安裝其他套件
# !pip3 install apyori gymnasium[classic_control] opencv-contrib-python jieba
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#      --------------------------------------- 0.0/19.2 MB 991.0 kB/s eta 0:00:20
#      ---------------------------------------- 0.2/19.2 MB 1.8 MB/s eta 0:00:11
#       --------------------------------------- 0.4/19.2 MB 2.7 MB/s eta 0:00:07
#      - -------------------------------------- 0.6/19.2 MB 3.3 MB/s eta 0:00:06
#      - -------------------------------------- 0.6/19.2 MB 2.7 MB/s eta 0:00:07
#      -- ------------------------------------- 1.2/19.2 MB 4.2 MB/s eta 0:00:05
#      --- ------------------------------------ 1.5/19.2 MB 4.4 MB/s eta 0:00:05
#      --- ------------------------------------ 1.5/19.2 MB 4.7 MB/s eta 0:00:04
#      ---- ----------------------------------- 2.0/19.2 MB 4.9 MB/s eta 0:00:04
#      ---- ----------------------------------- 2.3/19.2 MB 5.1 MB/s eta 0:00:04
# ...
